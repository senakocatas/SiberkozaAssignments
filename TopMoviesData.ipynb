# %%
import pandas as pd
df = pd.read_csv('top_movies_data.csv')
df
# Out:
#       index  production_year       id  \
# 0         0             2006  4103791
# 1         1             2006  4022547
# 2         2             2006  3415583
# 3         3             2006  4587958
# 4         4             2006  4351263
# ...     ...              ...      ...
# 1190   1190             2017  3954779
# 1191   1191             2017  4375083
# 1192   1192             2016  4367698
# 1193   1193             2017  3342703
# 1194   1194             2017  4332562
#
#                                            title  \
# 0     Pirates of the Caribbean: Dead Man's Chest
# 1                            Night at the Museum
# 2                                           Cars
# 3                          X-Men: The Last Stand
# 4                              The Da Vinci Code
# ...                                          ...
# 1190                                Megan Leavey
# 1191                        The Greatest Showman
# 1192                                 The Founder
# ...

# %%
import pandas as pd
df = pd.read_csv('top_movies_data.csv')
df.shape
# Out:
# (1195, 11)

# %%
df.describe()
# Out:
#              index  production_year            id        budget
# count  1195.000000      1195.000000  1.195000e+03  1.195000e+03
# mean    597.000000      2011.492887  3.974297e+06  6.582610e+07
# std     345.111093         3.434807  4.085474e+05  5.973894e+07
# min       0.000000      2006.000000  3.212915e+06  0.000000e+00
# 25%     298.500000      2008.500000  3.634968e+06  2.225000e+07
# 50%     597.000000      2011.000000  4.022548e+06  4.500000e+07
# 75%     895.500000      2014.000000  4.361250e+06  9.000000e+07
# max    1194.000000      2017.000000  4.607464e+06  3.785000e+08

# %%
df.values
# Out:
# array([[0, 2006, 4103791, ..., 225000000, 'the-numbers', 'F'],
#        [1, 2006, 4022547, ..., 110000000, 'the-numbers', 'F'],
#        [2, 2006, 3415583, ..., 70000000, 'the-numbers', 'D'],
#        ...,
#        [1192, 2016, 4367698, ..., 10500000, 'the-numbers', 'D'],
#        [1193, 2017, 3342703, ..., 25000000, 'the-numbers', 'F'],
#        [1194, 2017, 4332562, ..., 10500000, 'imdb', 'F']], dtype=object)
